# %%
import pandas as pd

# %%
url = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhv/fhv_tripdata_2019-02.csv.gz'

# %%
df = pd.read_csv(url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1707649 entries, 0 to 1707648
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   dispatching_base_num    object
#  1   pickup_datetime         object
#  2   dropOff_datetime        object
#  3   PUlocationID            float64
#  4   DOlocationID            float64
#  5   SR_Flag                 float64
#  6   Affiliated_base_number  object
# dtypes: float64(3), object(4)
# memory usage: 91.2+ MB

# %%
len(df)
# Out:
# 1707649

# %%
df.head()
# Out:
#   dispatching_base_num      pickup_datetime     dropOff_datetime  \
# 0               B00037  2019-02-01 00:08:44  2019-02-01 00:23:35
# 1               B00037  2019-02-01 00:27:51  2019-02-01 00:32:54
# 2               B00037  2019-02-01 00:18:30  2019-02-01 00:25:45
# 3               B00037  2019-02-01 00:43:15  2019-02-01 00:48:29
# 4               B00037  2019-02-01 00:01:45  2019-02-01 00:09:13
#
#    PUlocationID  DOlocationID  SR_Flag Affiliated_base_number
# 0         264.0         265.0      NaN                 B00037
# 1         264.0         265.0      NaN                 B00037
# 2         264.0         265.0      NaN                 B00037
# 3         264.0         265.0      NaN                 B00037
# 4         264.0         265.0      NaN                 B00037

# %%
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])
df['dropOff_datetime'] = pd.to_datetime(df['dropOff_datetime'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1707649 entries, 0 to 1707648
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   dispatching_base_num    object
#  1   pickup_datetime         datetime64[ns]
#  2   dropOff_datetime        datetime64[ns]
#  3   PUlocationID            float64
#  4   DOlocationID            float64
#  5   SR_Flag                 float64
#  6   Affiliated_base_number  object
# dtypes: datetime64[ns](2), float64(3), object(2)
# memory usage: 91.2+ MB

# %%
for i in range(12):
    month = '0' + str(i+1)
    month = month[-2:]

    df = pd.read_parquet(f'fhv_tripdata_2019-{month}.parquet')
    df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23143222 entries, 0 to 23143221
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count     Dtype
# ---  ------                  --------------     -----
#  0   Unnamed: 0              23143222 non-null  int64
#  1   dispatching_base_num    23143219 non-null  object
#  2   pickup_datetime         23143222 non-null  datetime64[ns]
#  3   dropOff_datetime        23143222 non-null  datetime64[ns]
#  4   PUlocationID            21323952 non-null  float64
#  5   DOlocationID            22478513 non-null  float64
#  6   SR_Flag                 5379452 non-null   float64
#  7   Affiliated_base_number  20811894 non-null  object
# dtypes: datetime64[ns](2), float64(3), int64(1), object(2)
# memory usage: 1.4+ GB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1707649 entries, 0 to 1707648
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count    Dtype
# ...

# %%
df = pd.read_parquet('./fhv_tripdata_2019-01.parquet')
df['DOlocationID'].unique()
# Out:
# array([ nan, 265.,  52., 237., 236.,  85., 246., 224.,  14., 233.,  87.,
#        229.,  16.,  15.,  82.,  92., 252.,  70., 223., 162.,  75., 238.,
#         98.,  74.,  61., 206., 156., 211., 257.,  65.,  39., 181., 129.,
#        179., 173.,  71.,  56., 113., 161., 220.,  88., 141.,   7., 263.,
#         19.,  45.,  72.,   3., 254.,  81., 259.,  51.,   0., 244., 247.,
#        169.,  83.,  73.,  93., 192.,  67., 135.,   6., 221.,  48., 144.,
#        112., 145., 225.,  54.,  78., 243.,  79.,  41., 210., 126., 168.,
#         42., 119., 146.,  26., 205., 196.,  37.,  17.,  62., 262., 142.,
#        134., 251., 245., 186.,  36.,  77., 130., 213., 250., 116.,  80.,
#        235., 242.,  69., 248., 167., 182., 118.,  68.,  25., 255.,  31.,
#        258., 241., 131., 228.,  55.,  33., 133., 230., 158.,  95., 170.,
#        188., 136., 177.,  89., 226., 148., 106., 203.,  66., 195., 107.,
#        185.,  47., 232., 239.,  97., 164., 151., 174.,  11., 234., 100.,
# ...
